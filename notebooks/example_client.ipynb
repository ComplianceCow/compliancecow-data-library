# %%
from compliancecow.models import cowlib, cowreport
from compliancecow.utils import utils

# generated by user
auth_token = ''
client = cowlib.Client(auth_token=auth_token)
client

# %%
plans, errors = client.get_plans(ids=['616a3c41-e351-41f5-a0f1-c064d3e6b30b'])
print('errors :',errors)
plans

# %%
plan_instances, errors = client.get_plan_instances(plan=plans[0]) # or plan_id
print('errors :',errors)
plan_instance = plan_instances[0]


### available params :
#along_with_heirarchy=False,
#having_evidences=False,
#having_notes=False,
#having_attachments=False,
#having_checklist=False,
#automated=True

controls = plan_instance.get_plan_instance_controls(having_evidences=True)
controls

# %%
data, errors = client.get_evidence_data(evidence=controls[0].evidences[0])
print('errors :',errors)
data

# %%
configurations, error = client.get_configurations() #id , is_meta_data_to_be_return=True will return the subscriptions
print('error :', error)
configurations[0].to_dict()
# Out:
# error : None
# {'id': 'a14bf23e-0959-496e-974f-3faa74b2ab1d',
#  'name': 'New_testing_Config',
#  'description': 'testing',
#  'type': 'azure',
#  'cloudType': 'azure',
#  'planID': '00000000-0000-0000-0000-000000000000',
#  'planInstanceID': '00000000-0000-0000-0000-000000000000',
#  'domainID': '2a371040-d8f0-4405-b5c5-3fe925f64018',
#  'orgID': '2f95c66e-7aba-4dbe-ae4a-e0104a24984a',
#  'groupID': '23fc85f4-1ae0-4186-be9f-87fac32e0e52',
#  'createdBy': '187c2c21-c86b-47d0-9ed4-883f117661a0',
#  'status': 'validated',
#  'availabilityLevel': 'domain',
#  'createdAt': '2021-03-15T04:20:49',
#  'lastUpdatedBy': '187c2c21-c86b-47d0-9ed4-883f117661a0',
#  'lastUpdatedAt': '2021-03-15T04:20:49'}

# %%
#category_name, dashboard_name, report_name, plan_name
categories, errors = client.get_dashboard_categories('c05b83b1-4d19-4da3-b37b-3da3b0865ca2')
print('error :', errors)
categories[0].to_dict()
# Out:
# error : None
# {'id': '51785ebb-ec15-4b88-a39d-dd45a12bdc9b',
#  'name': 'Application Vulnerability'}

# %%
dashboards, errors = client.get_dashboards('c05b83b1-4d19-4da3-b37b-3da3b0865ca2','51785ebb-ec15-4b88-a39d-dd45a12bdc9b')
print('error :', errors)
dashboards[0].to_dict()
# Out:
# error : None
# {'id': '63d4bdbe-8ba7-4c0a-a734-80ef9b53a414', 'name': 'Vulnerabilty Summary'}

# %%
reports, errors = client.get_reports(dashboard_id='63d4bdbe-8ba7-4c0a-a734-80ef9b53a414')
print('error :', errors)
reports[0].to_dict()
# Out:
# error : None
# {'id': '8555a644-c4d7-4e9c-b468-b67808ec9e83',
#  'name': 'User Logins After Termination',
#  'categoryName': 'Application Vulnerability',
#  'categoryId': '51785ebb-ec15-4b88-a39d-dd45a12bdc9b',
#  'planIds': ['c05b83b1-4d19-4da3-b37b-3da3b0865ca2',
#   '616a3c41-e351-41f5-a0f1-c064d3e6b30b'],
#  'tags': ['report']}

# %%
report_data, errors = client.get_report_data(report_name='complaince_cow_vuls_issue_tracker_user_logins',format_type=cowreport.DataType.PARQUET)
print('error :', errors)
print('report_data.data_type :',report_data.data_type)
df , errors = utils.convert_data_to_df(report_data) # 'parquet' or 'json' or return error
df
# Out:
# error : None
# report_data.data_type : parquet
#     index State/Province Country Postcode  Longitude  Latitude  \
# 0       0              7      AD    AD500       1.53     42.51
# 1       1             AJ      AE     None      55.47     25.42
# 2       2             AJ      AE     None      55.47     25.39
# 3       3             AZ      AE     None      54.38     24.48
# 4       4             AZ      AE     None      54.54     24.51
# ..    ...            ...     ...      ...        ...       ...
# 95     95             DU      AE     None      55.42     25.13
# 96     96             DU      AE     None      55.19     25.13
# 97     97             DU      AE     None      55.28     25.21
# 98     98             DU      AE     None      55.12     25.05
# 99     99             DU      AE     None      55.41     25.22
#
#                                Street Address  Store Number
# 0                           Av. Meritxell, 96  47370-257954
# 1                        1 Street 69, Al Jarf  22331-212325
# 2                Sheikh Khalifa Bin Zayed St.  47089-256771
# 3                             Al Salam Street  22126-218024
# 4             Khaldiya Area, Abu Dhabi Island  17127-178586
# ..                                        ...           ...
# 95     Academic City Rd, main food court area   6106-148051
# 96                                   Jumeirah   34317-95971
# 97            Sheikh Zayed Road, Ground Floor  32269-114734
# 98  Jebel Ali Gardens, Gardens II China Court   34337-97975
# 99    Cnr of Tripoli St & Emirates Rd. Mirdif   4143-147546
#
# [100 rows x 8 columns]

# %%
report_data, errors = client.get_report_schema(report_name='complaince_cow_vuls_issue_tracker_user_logins')
print('error :', errors)
report_data


#from_parquet_to_df(parquet_bytes)
#from_json_to_df(json)
# Out:
# error : None
